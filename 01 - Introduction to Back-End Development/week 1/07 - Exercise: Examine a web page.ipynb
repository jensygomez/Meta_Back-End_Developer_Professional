# %% [markdown]
# **Author:**       Jensy Gregorio Gómez
# ---------------------------------------
# **Profession:**  IT Support Analyst
# **Date:**         19 Febrero 2024
# **Location:**     Vila Isabel, Curitiba/PR
#
#
# ---
#
# **Contacto:**
#
# - **Email:** [contact@jensygomez.us](mailto:contact@jensygomez.us)
# - **YouTube:** [Tu Canal de YouTube](https://www.youtube.com/@systechcwb826)
# - **LinkedIn:** [Tu Perfil de LinkedIn](https://www.linkedin.com/in/jensygomez/)

# %% [markdown]
# # Exercise: Examine a web page
#
# ### Introduction
#
# In this exercise, you will practice examining an HTML page using the developer tools.
#
# ### Goal
#
# -   Inspect the HTML document using the developer tools in your browser.
#
#
# ### Objectives
#
# -   Find the HTML ID of the Little Lemon logo.
#
#
# ### Instructions
#
# **Step 1:** Download the following file on your local system.
#
# [](https://d3c33hcgiwev3.cloudfront.net/87FmqOJ9RLqxZqjifZS6wg_49b1f0d2659c4a8ea0cf9e9db16505e1_examine_the_page.zip?Expires=1708473600&Signature=KtkzqqHLNVLKtLOELIDs3EZ8vslJGTmFGpCiStsSPJoCV~IBF4YMSaZgIoEpTal019bcWMVICKQCjOq6TsGuxIlJ4dOZTV4wYrTeKSBhUUccV9JDuiN~egdp-xTxjiT7rCV62ZAAvhkZcbjfvXd-M3wDqMs~zCqxOfwGtOY2iWk_&Key-Pair-Id=APKAJLTNE6QMUY6HBC5A)
#
# examine_the_page
#
# ZIP File
#
# **Step 2:** Unzip the file.
#
# On Windows, open your Downloads folder, right-click the file _examine_the_page.zip_ and select Extract All.
#
# ![Display for Unzipping to Select Destination and Extract Files](https://d3c33hcgiwev3.cloudfront.net/imageAssetProxy.v1/Pb-z1BKOT2y_s9QSji9sUQ_2d7edd4bc1e744b68194e2b170c327e1_windows_unzip.PNG?expiry=1708473600000&hmac=T4wMCFA98uivm3ax6yw3JVd2PctDS1U3LBB7nqwER2Q)
#
# On Mac, open your Downloads folder and double click the file _examine_the_page.zip_.
#
# Once unzipped, there will be a folder named _examine_the_page_.
#
# **Step 3:** Open the folder and double click index.html to view the file in your local web browser. Verify that it looks like this:
#
# ![Little Lemon Our Menu Webpage preview](https://d3c33hcgiwev3.cloudfront.net/imageAssetProxy.v1/x4JuIEfETeeCbiBHxI3n-w_f7de1bf8d53c4dbcb83e55ed431c77a1_Examine-Web-Page.jpeg?expiry=1708473600000&hmac=dF1gM0VfOt5Yvx9FtW3zfLc5qOwdZR8ENxUsFo3f8DI)
#
# **Step 4:** Right-click the Little Lemon logo and select Inspect (or Inspect Element)
#
# ![Right Click Display on the Page](https://d3c33hcgiwev3.cloudfront.net/imageAssetProxy.v1/XtHleW-UQQmR5XlvlEEJmQ_291e0b5151d145239a7565ca438838e1_little_lemon_logo_right_click.png?expiry=1708473600000&hmac=bZZ328R4fiDvOyt86s2X9Oin5D1f72tIJGOKuXSHUiw)
#
# **Step 5:** Inspect the line in the HTML for the logo in the developer tools panel. The line begins with <img.
#
# **Note:** In the line, there is an ID in the following format id="???". Note the value that the ID is equal to.
#
# ![Inspect code for img tag](https://d3c33hcgiwev3.cloudfront.net/imageAssetProxy.v1/zG_k-s5KRLKv5PrOSvSyOA_a9c515ff782f4404b7f94d129b2afaa1_examine_page_inspect_logo.png?expiry=1708473600000&hmac=0gqbwOFEuOM0suAgSXcD-Ns9tuE-a0WgUfC6qK28K8w)
#
# ![Inspect code for  id value inside img tag](https://d3c33hcgiwev3.cloudfront.net/imageAssetProxy.v1/CAQajjMWTkSEGo4zFm5E6A_4e64364cd2704391a31ddb8a2956eba1_examine_page_inspect_logo_id.png?expiry=1708473600000&hmac=5CtTbfi5PaLWLAhZ2dtTQy3lqp2Dbc7jn0pr2cwz3jY)
#
# ### Tips
#
# -   If you get stuck, close the developer tools and start over.
#
# -   Review the lesson _Developer Tools_.
